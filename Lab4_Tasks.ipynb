# %%
# Student Identity
LAST_NAME = "Lapitan"  # Replace with your surname
STUDENT_ID = "TUPM-25-1298"  # Replace with your ID

# Derive computational parameters
seed_digit = int(STUDENT_ID[-1])
id_checksum = sum(int(d) for d in STUDENT_ID if d.isdigit())
vector_dim = len(LAST_NAME)

# Encapsulate state into a Dictionary
sys_config = {
    "operator": LAST_NAME,
    "auth_id": STUDENT_ID,
    "base_seed": seed_digit,
    "checksum": id_checksum,
    "vector_dim": vector_dim,
    "status": "INITIALIZED"
}

# Display system state
print("=== SYSTEM CONFIGURATION ===")
for key, value in sys_config.items():
    print(f"{key.upper()}: {value}")
# Out:
# === SYSTEM CONFIGURATION ===
# OPERATOR: Lapitan
# AUTH_ID: TUPM-25-1298
# BASE_SEED: 8
# CHECKSUM: 27
# VECTOR_DIM: 7
# STATUS: INITIALIZED

# %%
base_val = sys_config["base_seed"]
number_sequence = [base_val, base_val + 15, sys_config["checksum"]]
print(f"Initial Sequence: {number_sequence}")

# Append a new value
number_sequence.append(base_val + 20)
print(f"After Append: {number_sequence}")
# Out:
# Initial Sequence: [8, 23, 27]
# After Append: [8, 23, 27, 28]

# %%
new_numbers = [base_val + 5, sys_config["vector_dim"], base_val]
number_sequence.extend(new_numbers)
print(f"After Extend: {number_sequence}")

# Count and Sort
base_count = number_sequence.count(base_val)
print(f"Occurrences of {base_val}: {base_count}")

number_sequence.sort()
print(f"Sorted Sequence: {number_sequence}")
# Out:
# After Extend: [8, 23, 27, 28, 13, 7, 8]
# Occurrences of 8: 2
# Sorted Sequence: [7, 8, 8, 13, 23, 27, 28]

# %%
fixed_coordinates = (sys_config["vector_dim"], sys_config["base_seed"], 0)
print(f"Fixed Coordinates: {fixed_coordinates}")

# Unpack tuple
x_val, y_val, z_val = fixed_coordinates
print(f"Unpacked Values -> X: {x_val}, Y: {y_val}, Z: {z_val}")

# Attempt to modify (Expected to fail)
try:
    fixed_coordinates[0] = 99
except TypeError as error_msg:
    print(f"Modification Error: {error_msg}")
# Out:
# Fixed Coordinates: (7, 8, 0)
# Unpacked Values -> X: 7, Y: 8, Z: 0
# Modification Error: 'tuple' object does not support item assignment

# %%
data_payload = {
    "identifier": sys_config["auth_id"],
    "dimension": sys_config["vector_dim"],
    "status": "active"
}

# Display items
print("--- Payload Data ---")
for key, value in data_payload.items():
    print(f"{key.capitalize()}: {value}")

# Dynamic update
data_payload["efficiency_rating"] = 98.5
print(f"\nUpdated Payload: {data_payload}")
# Out:
# --- Payload Data ---
# Identifier: TUPM-25-1298
# Dimension: 7
# Status: active
#
# Updated Payload: {'identifier': 'TUPM-25-1298', 'dimension': 7, 'status': 'active', 'efficiency_rating': 98.5}

# %%
base_val = sys_config["base_seed"]
raw_data = [base_val, base_val + 5, base_val, sys_config["vector_dim"], base_val + 5]
print(f"Raw List (with duplicates): {raw_data}")

# Convert to Set
unique_data = set(raw_data)
print(f"Unique Set: {unique_data}")
# Out:
# Raw List (with duplicates): [8, 13, 8, 7, 13]
# Unique Set: {8, 13, 7}

# %%
reference_set = {base_val, base_val + 10, base_val + 20}
print(f"Reference Set: {reference_set}")

# Intersections and Unions
common_elements = unique_data.intersection(reference_set)
combined_elements = unique_data.union(reference_set)

print(f"Intersection (Common): {common_elements}")
print(f"Union (Combined): {combined_elements}")
# Out:
# Reference Set: {8, 18, 28}
# Intersection (Common): {8}
# Union (Combined): {18, 7, 8, 28, 13}

# %%
import array
number_array = array.array('i', [sys_config["base_seed"], sys_config["vector_dim"], 100])
print(f"Integer Array: {number_array}")

# Attempt to append invalid type
try:
    number_array.append("invalid")
except TypeError as error_msg:
    print(f"Type Error: {error_msg}")
# Out:
# Integer Array: array('i', [8, 7, 100])
# Type Error: 'str' object cannot be interpreted as an integer

# %%
base_val = sys_config["base_seed"]
generated_list = [(x * base_val) for x in range(1, 6)]
print(f"Generated Comprehension: {generated_list}")

filtered_list = [x for x in generated_list if x > 15]
print(f"Filtered Comprehension (Values > 15): {filtered_list}")
# Out:
# Generated Comprehension: [8, 16, 24, 32, 40]
# Filtered Comprehension (Values > 15): [16, 24, 32, 40]

# %%
from collections import deque
data_queue = deque([sys_config["base_seed"], sys_config["vector_dim"]])
print(f"Initial Deque: {data_queue}")

# Append to both ends
data_queue.append(100)
data_queue.appendleft(200)
print(f"After Appends: {data_queue}")

# Remove from left
data_queue.popleft()
print(f"Final Deque (After Popleft): {data_queue}")
# Out:
# Initial Deque: deque([8, 7])
# After Appends: deque([200, 8, 7, 100])
# Final Deque (After Popleft): deque([8, 7, 100])

# %%
from collections import defaultdict
default_data = defaultdict(int)
default_data['active_key'] = sys_config["vector_dim"]

print(f"Existing Key Value: {default_data['active_key']}")
# Missing key won't crash
print(f"Missing Key Value (Auto-generated): {default_data['unknown_key']}")
# Out:
# Existing Key Value: 7
# Missing Key Value (Auto-generated): 0

# %%
surname = "Lapitan"
unique_chars = set(surname.upper())
char_count = len(unique_chars)

print(f"Surname: {surname}")
print(f"Unique Characters: {unique_chars}")
print(f"Total Unique Count: {char_count}")
# Out:
# Surname: Lapitan
# Unique Characters: {'L', 'T', 'A', 'I', 'N', 'P'}
# Total Unique Count: 6

# %%
from collections import deque

# Initialize task queue
task_queue = deque(["System_Init", "Auth_Check", "Data_Sync"])
print(f"Initial Tasks: {list(task_queue)}")

# Add a high-priority emergency task to the front
task_queue.appendleft("EMERGENCY_SHUTDOWN")
print(f"Emergency Task Added: {list(task_queue)}")

# Remove and complete the first task
completed_task = task_queue.popleft()
print(f"Executed Task: {completed_task}")
print(f"Remaining Tasks: {list(task_queue)}")
# Out:
# Initial Tasks: ['System_Init', 'Auth_Check', 'Data_Sync']
# Emergency Task Added: ['EMERGENCY_SHUTDOWN', 'System_Init', 'Auth_Check', 'Data_Sync']
# Executed Task: EMERGENCY_SHUTDOWN
# Remaining Tasks: ['System_Init', 'Auth_Check', 'Data_Sync']

# %%
from collections import defaultdict

error_log = defaultdict(int)
errors_encountered = ["TypeError", "NameError", "TypeError", "SyntaxError", "TypeError"]

for err in errors_encountered:
    error_log[err] += 1

print("--- Error Frequency Log ---")
for err_type, count in error_log.items():
    print(f"{err_type}: {count} occurrences")
# Out:
# --- Error Frequency Log ---
# TypeError: 3 occurrences
# NameError: 1 occurrences
# SyntaxError: 1 occurrences
